# %%
import pandas as pd
import json

df = pd.read_json('train-1.json')
display(df)
df.shape
#change year into integers.
# Out:
#                                  doi  \
# 0                10.3115/v1/P15-1039
# 1     10.18653/v1/2020.eval4nlp-1.12
# 2               10.18653/v1/W17-3516
# 3               10.18653/v1/S17-2160
# 4               10.18653/v1/W15-2205
# ...                              ...
# 9653             10.3115/v1/W14-0202
# 9654  10.26615/978-954-452-058-8_001
# 9655     10.18653/V1/2021.SMM4H-1.16
# 9656      10.18653/v1/2021.case-1.22
# 9657         10.3115/1075218.1075259
#
#                                                   title  \
# 0     Generating High Quality Proposition Banks for ...
# 1     One of these words is not like the other: a re...
# 2     The Code2Text Challenge: Text Generation in So...
# 3     The Meaning Factory at SemEval-2017 Task 9: Pr...
# 4               Semantic Parsing for Textual Entailment
# ...                                                 ...
# 9653  IBM’s Belief Tracker: Results On Dialog State ...
# 9654  RANLP 2019 Multilingual Headline Generation Ta...
# ...

# %%
df.head()
# Out:
#                               doi  \
# 0             10.3115/v1/P15-1039
# 1  10.18653/v1/2020.eval4nlp-1.12
# 2            10.18653/v1/W17-3516
# 3            10.18653/v1/S17-2160
# 4            10.18653/v1/W15-2205
#
#                                                title  \
# 0  Generating High Quality Proposition Banks for ...
# 1  One of these words is not like the other: a re...
# 2  The Code2Text Challenge: Text Generation in So...
# 3  The Meaning Factory at SemEval-2017 Task 9: Pr...
# 4            Semantic Parsing for Textual Entailment
#
#                                             abstract  \
# 0  Semantic role labeling (SRL) is crucial to nat...
# 1  Word embeddings are an active topic in the NLP...
# 2  We propose a new shared task for tactical data...
# 3  We evaluate a semantic parser based on a chara...
# 4  In this paper we gauge the utility of general-...
#
#                                              authors        venue    year  \
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

mod_df = df.dropna()
print(mod_df)
# Out:
#                                  doi  \
# 0                10.3115/v1/P15-1039
# 1     10.18653/v1/2020.eval4nlp-1.12
# 2               10.18653/v1/W17-3516
# 3               10.18653/v1/S17-2160
# 4               10.18653/v1/W15-2205
# ...                              ...
# 9652             10.3115/v1/W14-3208
# 9653             10.3115/v1/W14-0202
# 9654  10.26615/978-954-452-058-8_001
# 9655     10.18653/V1/2021.SMM4H-1.16
# 9657         10.3115/1075218.1075259
#
#                                                   title  \
# 0     Generating High Quality Proposition Banks for ...
# 1     One of these words is not like the other: a re...
# 2     The Code2Text Challenge: Text Generation in So...
# 3     The Meaning Factory at SemEval-2017 Task 9: Pr...
# 4               Semantic Parsing for Textual Entailment
# ...                                                 ...
# 9652  Applying prosodic speech features in mental he...
# 9653  IBM’s Belief Tracker: Results On Dialog State ...
# ...

# %%
mod_df.head()
# Out:
#                               doi  \
# 0             10.3115/v1/P15-1039
# 1  10.18653/v1/2020.eval4nlp-1.12
# 2            10.18653/v1/W17-3516
# 3            10.18653/v1/S17-2160
# 4            10.18653/v1/W15-2205
#
#                                                title  \
# 0  Generating High Quality Proposition Banks for ...
# 1  One of these words is not like the other: a re...
# 2  The Code2Text Challenge: Text Generation in So...
# 3  The Meaning Factory at SemEval-2017 Task 9: Pr...
# 4            Semantic Parsing for Textual Entailment
#
#                                             abstract  \
# 0  Semantic role labeling (SRL) is crucial to nat...
# 1  Word embeddings are an active topic in the NLP...
# 2  We propose a new shared task for tactical data...
# 3  We evaluate a semantic parser based on a chara...
# 4  In this paper we gauge the utility of general-...
#
#                                              authors        venue    year  \
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

mod_df = df.dropna()
print(mod_df)
mod_df.head() #AS YOU CAN SEE, THERE HAS BEEN A REMOVAL OF 9658 - 9381
# Out:
#                                  doi  \
# 0                10.3115/v1/P15-1039
# 1     10.18653/v1/2020.eval4nlp-1.12
# 2               10.18653/v1/W17-3516
# 3               10.18653/v1/S17-2160
# 4               10.18653/v1/W15-2205
# ...                              ...
# 9652             10.3115/v1/W14-3208
# 9653             10.3115/v1/W14-0202
# 9654  10.26615/978-954-452-058-8_001
# 9655     10.18653/V1/2021.SMM4H-1.16
# 9657         10.3115/1075218.1075259
#
#                                                   title  \
# 0     Generating High Quality Proposition Banks for ...
# 1     One of these words is not like the other: a re...
# 2     The Code2Text Challenge: Text Generation in So...
# 3     The Meaning Factory at SemEval-2017 Task 9: Pr...
# 4               Semantic Parsing for Textual Entailment
# ...                                                 ...
# 9652  Applying prosodic speech features in mental he...
# 9653  IBM’s Belief Tracker: Results On Dialog State ...
# ...

# %%
import numpy as np
display(mod_df.dtypes)
mod_df['year'] = mod_df['year'].apply(np.int64)
display(mod_df)
# Out:
# doi                object
# title              object
# abstract           object
# authors            object
# venue              object
# year                int64
# references          int64
# topics             object
# is_open_access       bool
# fields_of_study    object
# citations           int64
# dtype: object
# <ipython-input-7-7fe68da139bb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mod_df['year'] = mod_df['year'].apply(np.int64)
#                                  doi  \
# 0                10.3115/v1/P15-1039
# 1     10.18653/v1/2020.eval4nlp-1.12
# 2               10.18653/v1/W17-3516
# 3               10.18653/v1/S17-2160
# 4               10.18653/v1/W15-2205
# ...                              ...
# ...

# %%
mod_df["is_open_access"].value_counts(dropna = False)
# Out:
# True     7843
# False    1538
# Name: is_open_access, dtype: int64
